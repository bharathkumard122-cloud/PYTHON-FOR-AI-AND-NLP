# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
text = "Barack Obama was born in Hawaii. He was the 44th President of the United States."

# %%
nltk.download('punkt_tab')
sentences = nltk.sent_tokenize(text)

print("Sentences:")
for s in sentences:
    print(s)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Sentences:
# Barack Obama was born in Hawaii.
# He was the 44th President of the United States.

# %%
for s in sentences:
    tokens = nltk.word_tokenize(s)
    print("\nTokens:", tokens)
# Out:
# Tokens: ['Barack', 'Obama', 'was', 'born', 'in', 'Hawaii', '.']
#
# Tokens: ['He', 'was', 'the', '44th', 'President', 'of', 'the', 'United', 'States', '.']

# %%
for s in sentences:
    tokens = nltk.word_tokenize(s)
    pos_tags = nltk.pos_tag(tokens)
    print("\nPOS Tags:", pos_tags)
# Out:
# POS Tags: [('Barack', 'NNP'), ('Obama', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), ('Hawaii', 'NNP'), ('.', '.')]
#
# POS Tags: [('He', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('44th', 'JJ'), ('President', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('.', '.')]

# %%
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
for s in sentences:
    tokens = nltk.word_tokenize(s)
    pos_tags = nltk.pos_tag(tokens)
    ne_tree = nltk.ne_chunk(pos_tags)
    print("\nNamed Entity Tree:")
    print(ne_tree)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# Named Entity Tree:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP)
#   ./.)
#
# Named Entity Tree:
# (S
#   He/PRP
#   was/VBD
#   the/DT
#   44th/JJ
#   President/NNP
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   ./.)

# %%
print("\nExtracted Named Entities:\n")

for s in sentences:
    tokens = nltk.word_tokenize(s)
    pos_tags = nltk.pos_tag(tokens)
    ne_tree = nltk.ne_chunk(pos_tags)

    for chunk in ne_tree:
        if hasattr(chunk, "label"):
            entity = " ".join([word for word, tag in chunk.leaves()])
            print(chunk.label(), ":", entity)
# Out:
# Extracted Named Entities:
#
# PERSON : Barack
# PERSON : Obama
# GPE : Hawaii
# GPE : United States
